# %%
import wave
obj = wave.open('/home/kishan/Downloads/sample.wav','r')
print( "Number of channels",obj.getnchannels())
print ( "Sample width",obj.getsampwidth())
print ( "Frame rate.",obj.getframerate())
print ("Number of frames",obj.getnframes())
print ( "parameters:",obj.getparams())
# print(obj.readframes(10000000000000))
data = obj.readframes(-1)
print(type(data))
print(data)
sampleRate = 44100.0 # hertz
duration = 1.0 # seconds
frequency = 440.0 # hertz
writeobj = wave.open('/home/kishan/Downloads/sound.wav','w')
writeobj.setnchannels(1) # mono
writeobj.setsampwidth(2)
writeobj.setframerate(sampleRate)
writeobj.writeframesraw( data )
obj.close()
# Out:
# Number of channels 1
# Sample width 2
# Frame rate. 44100
# Number of frames 440000
# parameters: _wave_params(nchannels=1, sampwidth=2, framerate=44100, nframes=440000, comptype='NONE', compname='not compressed')
# <class 'bytes'>
# ...

# %%
import wave, struct, math, random
sampleRate = 44100.0 # hertz
duration = 1.0 # seconds
frequency = 440.0 # hertz
obj = wave.open('/home/kishan/Downloads/sound.wav','w')
obj.setnchannels(1) # mono
obj.setsampwidth(2)
obj.setframerate(sampleRate)
for i in range(99999):
#    value = random.randint(-32767, 32767)
#    data = struct.pack('<h', value)
    print(data)
    obj.writeframesraw( data )
obj.close()

# %%
# imports 
import matplotlib.pyplot as plt 
import numpy as np 
import wave, sys 

# shows the sound waves 
def visualize(path: str): 
	
	# reading the audio file 
	raw = wave.open(path) 
	
	# reads all the frames 
	# -1 indicates all or max frames 
	signal = raw.readframes(10) 
	signal = np.frombuffer(signal, dtype ="int16") 
	
	# gets the frame rate 
	f_rate = raw.getframerate() 

	# to Plot the x-axis in seconds 
	# you need get the frame rate 
	# and divide by size of your signal 
	# to create a Time Vector 
	# spaced linearly with the size 
	# of the audio file 
	time = np.linspace( 
		0, # start 
		len(signal) / f_rate, 
		num = len(signal) 
	) 

	# using matlplotlib to plot 
	# creates a new figure 
	plt.figure(1) 
	
	# title of the plot 
	plt.title("Sound Wave") 
	
	# label of x-axis 
	plt.xlabel("Time") 
	
	# actual ploting 
	plt.plot(time, signal) 
	
	# shows the plot 
	# in new window 
	plt.show() 

	# you can also save 
	# the plot using 
	# plt.savefig('filename') 


if __name__ == "__main__": 

	visualize("/home/kishan/Downloads/sound.wav")

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys


spf = wave.open("/home/kishan/Downloads/sound.wav", "r")

# Extract Raw Audio from Wav File
signal = spf.readframes(500)
signal = np.fromstring(signal, "Int16")


# If Stereo
if spf.getnchannels() == 2:
    print("Just mono files")
    sys.exit(0)

plt.figure(1)
plt.title("Signal Wave...")
plt.plot(signal)
plt.show()
# Out:
# <ipython-input-31-3b9376a0c7f7>:11: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   signal = np.fromstring(signal, "Int16")
# <ipython-input-31-3b9376a0c7f7>:11: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   signal = np.fromstring(signal, "Int16")

# %%
data = {"TS":2768213,"Device ID":4545,"Intensity":0,"Status":0,"xadc":1879,"yadc":1814,"zadc":2302}

for i in data:
    print(i , ":" , data[i])
# Out:
# TS : 2768213
# Device ID : 4545
# Intensity : 0
# Status : 0
# xadc : 1879
# yadc : 1814
# zadc : 2302

# %%
import pyaudio
import wave

chunk = 1024  # Record in chunks of 1024 samples
sample_format = pyaudio.paInt16  # 16 bits per sample
channels = 2
fs = 44100  # Record at 44100 samples per second
seconds = 3
filename = "output.wav"

p = pyaudio.PyAudio()  # Create an interface to PortAudio

print('Recording')

stream = p.open(format=sample_format,
                channels=channels,
                rate=fs,
                frames_per_buffer=chunk,
                input=True)

frames = []  # Initialize array to store frames

# Store data in chunks for 3 seconds
for i in range(0, int(fs / chunk * seconds)):
    data = stream.read(chunk)
    frames.append(data)

# Stop and close the stream 
stream.stop_stream()
stream.close()
# Terminate the PortAudio interface
p.terminate()

print('Finished recording')

# Save the recorded data as a WAV file
wf = wave.open(filename, 'wb')
wf.setnchannels(channels)
wf.setsampwidth(p.get_sample_size(sample_format))
wf.setframerate(fs)
wf.writeframes(b''.join(frames))
wf.close()
# Out:
# Could not import the PyAudio C module '_portaudio'.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-8c4c2e1343c9> in <module>
# ----> 1 import pyaudio
#       2 import wave
#       3
#       4 chunk = 1024  # Record in chunks of 1024 samples
#       5 sample_format = pyaudio.paInt16  # 16 bits per sample
#
# ~/.local/lib/python3.8/site-packages/pyaudio.py in <module>
#     114 # attempt to import PortAudio
#     115 try:
# --> 116     import _portaudio as pa
#     117 except ImportError:
#     118     print("Could not import the PyAudio C module '_portaudio'.")
#
# ImportError: libportaudio.so.2: cannot open shared object file: No such file or directory

# %%
import sounddevice as sd
from scipy.io.wavfile import write

fs = 44100  # Sample rate
seconds = 3  # Duration of recording

myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=2)
sd.wait()  # Wait until recording is finished
write('output.wav', fs, myrecording)  # Save as WAV file
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-4f5e38654c47> in <module>
# ----> 1 import sounddevice as sd
#       2 from scipy.io.wavfile import write
#       3
#       4 fs = 44100  # Sample rate
#       5 seconds = 3  # Duration of recording
#
# ~/.local/lib/python3.8/site-packages/sounddevice.py in <module>
#      70     else:
#      71         raise OSError('PortAudio library not found')
# ---> 72     _lib = _ffi.dlopen(_libname)
#      73 except OSError:
#      74     if _platform.system() == 'Darwin':
#
# OSError: cannot load library 'libportaudio.so.2': libportaudio.so.2: cannot open shared object file: No such file or directory
